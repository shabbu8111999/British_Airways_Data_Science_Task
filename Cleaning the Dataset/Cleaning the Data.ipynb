# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'BA_Feedbacks.csv')
df.head()
# Out:
#    Unnamed: 0                                            Reviews  \
# 0           0  ✅ Trip Verified |  Booked a flight from Buchar...
# 1           1  ✅ Trip Verified |  Booked online months ago an...
# 2           2  ✅ Trip Verified |  The flight was on time. The...
# 3           3  Not Verified |  Angry, disappointed, and unsat...
# 4           4  ✅ Trip Verified |  As an infrequent flyer, Bri...
#
#    Stars(Ratings)                Date         Country
# 0               5  12th November 2023         Romania
# 1               1   8th November 2023  United Kingdom
# 2               8   7th November 2023  United Kingdom
# 3               7   5th November 2023           Italy
# 4               2   5th November 2023  United Kingdom

# %%
df.shape
# Out:
# (4000, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      4000 non-null   int64
#  1   Reviews         4000 non-null   object
#  2   Stars(Ratings)  4000 non-null   int64
#  3   Date            4000 non-null   object
#  4   Country         4000 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 156.4+ KB

# %%
df.describe().T
# Out:
#                  count       mean          std  min     25%     50%      75%  \
# Unnamed: 0      4000.0  1999.5000  1154.844867  0.0  999.75  1999.5  2999.25
# Stars(Ratings)  4000.0     4.1065     3.098477  1.0    1.00     3.0     7.00
#
#                    max
# Unnamed: 0      3999.0
# Stars(Ratings)    10.0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# Reviews           0
# Stars(Ratings)    0
# Date              0
# Country           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns = 'Unnamed: 0', inplace = True, axis = 1)

# %%
df
# Out:
#                                                 Reviews  Stars(Ratings)  \
# 0     ✅ Trip Verified |  Booked a flight from Buchar...               5
# 1     ✅ Trip Verified |  Booked online months ago an...               1
# 2     ✅ Trip Verified |  The flight was on time. The...               8
# 3     Not Verified |  Angry, disappointed, and unsat...               7
# 4     ✅ Trip Verified |  As an infrequent flyer, Bri...               2
# ...                                                 ...             ...
# 3995  ✅ Verified Review | Lisbon to London with Brit...               3
# 3996  ✅ Verified Review |  The flight started in the...               1
# 3997  ✅ Verified Review |  The flight started badly ...               1
# 3998  Gatwick to Alicante. Crew friendly but a bit a...               9
# 3999  ✅ Verified Review |  London Heathrow to Bangko...               8
#
#                     Date         Country
# 0     12th November 2023         Romania
# 1      8th November 2023  United Kingdom
# 2      7th November 2023  United Kingdom
# 3      5th November 2023           Italy
# 4      5th November 2023  United Kingdom
# ...                  ...             ...
# 3995  14th November 2016        Portugal
# 3996  13th November 2016  United Kingdom
# 3997  12th November 2016  United Kingdom
# 3998  11th November 2016  United Kingdom
# 3999  10th November 2016  United Kingdom
#
# [4000 rows x 4 columns]

# %%
df.dtypes
# Out:
# Reviews           object
# Stars(Ratings)     int64
# Date              object
# Country           object
# dtype: object

# %%
len(df['Country'].value_counts())
# Out:
# 66

# %%
result = df.groupby('Date')['Country'].value_counts().reset_index(name = 'Count')
result = result.sort_values(by = ['Date', 'Count'], ascending = [True, False])
print(result[:30])
# Out:
#                   Date         Country  Count
# 0      10th April 2017       Australia      2
# 1      10th April 2017  United Kingdom      2
# 2      10th April 2018  United Kingdom      2
# 3      10th April 2019  United Kingdom      2
# 4      10th April 2023  United Kingdom      2
# 5     10th August 2019       Australia      2
# 6     10th August 2022   United States      2
# 7   10th December 2016           China      2
# 8   10th December 2016  United Kingdom      2
# 9   10th December 2017  United Kingdom      4
# 10  10th December 2018        Malaysia      2
# 11  10th December 2019         Ireland      2
# 12  10th December 2022  United Kingdom      4
# 13  10th February 2017           Spain      2
# 14  10th February 2018  United Kingdom      2
# 15  10th February 2019  United Kingdom      2
# 16  10th February 2021        Bulgaria      2
# 17   10th January 2017  United Kingdom      4
# 18   10th January 2019   United States      4
# 19   10th January 2022    South Africa      2
# 20      10th July 2017  United Kingdom      8
# 21      10th July 2018  United Kingdom      6
# 22      10th July 2019          Canada      2
# 23      10th July 2019   United States      2
# 24      10th June 2017       Australia      2
# 25      10th June 2017  United Kingdom      2
# 26      10th June 2018  United Kingdom      2
# 27      10th June 2023  United Kingdom      2
# 28     10th March 2017  United Kingdom      4
# 29     10th March 2023  United Kingdom      4

# %%
df.rename(columns = {'Stars(Ratings)' : 'Ratings'}, inplace = True)

# %% [markdown]
# # Now let's Clean the Reviews column

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

df_corpus = []

for i in range(0, 4000):
    review = re.sub('[^a-zA-z]', ' ', df['Reviews'][i])
    review = review.lower()
    review = review.split()
    ps = PorterStemmer()
    all_stopwords = stopwords.words('english')
    all_stopwords.remove('not')
    review = [ps.stem(word) for word in review if not word in set(all_stopwords)]
    review = ' '.join(review)
    df_corpus.append(review)

# %%
df_new = pd.DataFrame(df_corpus)

# %%
df_new.rename(columns = {0 : 'New_Reviews'}, inplace = True)

# %%
df_new
# Out:
#                                             New_Reviews
# 0     trip verifi book flight bucharest manchest h l...
# 1     trip verifi book onlin month ago hitch replac ...
# 2     trip verifi flight time crew polit stori outwa...
# 3     not verifi angri disappoint unsatisfi rout lon...
# 4     trip verifi infrequ flyer british airway alway...
# ...                                                 ...
# 3995  verifi review lisbon london british airway nic...
# 3996  verifi review flight start first class concord...
# 3997  verifi review flight start badli call new conc...
# 3998  gatwick alicant crew friendli bit amateur busi...
# 3999  verifi review london heathrow bangkok british ...
#
# [4000 rows x 1 columns]

# %%
df = pd.concat([df, df_new], axis=1)
df
# Out:
#                                                 Reviews  Ratings  \
# 0     ✅ Trip Verified |  Booked a flight from Buchar...        5
# 1     ✅ Trip Verified |  Booked online months ago an...        1
# 2     ✅ Trip Verified |  The flight was on time. The...        8
# 3     Not Verified |  Angry, disappointed, and unsat...        7
# 4     ✅ Trip Verified |  As an infrequent flyer, Bri...        2
# ...                                                 ...      ...
# 3995  ✅ Verified Review | Lisbon to London with Brit...        3
# 3996  ✅ Verified Review |  The flight started in the...        1
# 3997  ✅ Verified Review |  The flight started badly ...        1
# 3998  Gatwick to Alicante. Crew friendly but a bit a...        9
# 3999  ✅ Verified Review |  London Heathrow to Bangko...        8
#
#                     Date         Country  \
# 0     12th November 2023         Romania
# 1      8th November 2023  United Kingdom
# 2      7th November 2023  United Kingdom
# 3      5th November 2023           Italy
# 4      5th November 2023  United Kingdom
# ...                  ...             ...
# 3995  14th November 2016        Portugal
# 3996  13th November 2016  United Kingdom
# 3997  12th November 2016  United Kingdom
# 3998  11th November 2016  United Kingdom
# 3999  10th November 2016  United Kingdom
#
#                                             New_Reviews
# 0     trip verifi book flight bucharest manchest h l...
# 1     trip verifi book onlin month ago hitch replac ...
# 2     trip verifi flight time crew polit stori outwa...
# 3     not verifi angri disappoint unsatisfi rout lon...
# 4     trip verifi infrequ flyer british airway alway...
# ...                                                 ...
# 3995  verifi review lisbon london british airway nic...
# 3996  verifi review flight start first class concord...
# 3997  verifi review flight start badli call new conc...
# 3998  gatwick alicant crew friendli bit amateur busi...
# 3999  verifi review london heathrow bangkok british ...
#
# [4000 rows x 5 columns]

# %%
df.to_csv('Cleaned BA Reviews.csv')

# %%
df.drop(columns = 'Reviews', inplace = True, axis = 1)

# %%
df
# Out:
#       Ratings                Date         Country  \
# 0           5  12th November 2023         Romania
# 1           1   8th November 2023  United Kingdom
# 2           8   7th November 2023  United Kingdom
# 3           7   5th November 2023           Italy
# 4           2   5th November 2023  United Kingdom
# ...       ...                 ...             ...
# 3995        3  14th November 2016        Portugal
# 3996        1  13th November 2016  United Kingdom
# 3997        1  12th November 2016  United Kingdom
# 3998        9  11th November 2016  United Kingdom
# 3999        8  10th November 2016  United Kingdom
#
#                                             New_Reviews
# 0     trip verifi book flight bucharest manchest h l...
# 1     trip verifi book onlin month ago hitch replac ...
# 2     trip verifi flight time crew polit stori outwa...
# 3     not verifi angri disappoint unsatisfi rout lon...
# 4     trip verifi infrequ flyer british airway alway...
# ...                                                 ...
# 3995  verifi review lisbon london british airway nic...
# 3996  verifi review flight start first class concord...
# 3997  verifi review flight start badli call new conc...
# 3998  gatwick alicant crew friendli bit amateur busi...
# 3999  verifi review london heathrow bangkok british ...
#
# [4000 rows x 4 columns]

# %% [markdown]
# So, here is the new reviews as you can see all the punctuations, tick marks, etc has been removed now it's good to go

# %%
df.to_csv('Perfect BA Reviews.csv')
